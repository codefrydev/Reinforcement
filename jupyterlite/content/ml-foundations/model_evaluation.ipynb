# %% [markdown]
# # ML Foundations — Model Evaluation
#
# Train/test split, confusion matrix, accuracy, precision, recall, and F1.
#
# **How to use:** Edit the `# TODO` cells and press **Shift+Enter** to run.

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('Imports ready.')

# %% [markdown]
# ## Exercise 1 — Confusion Matrix by Hand
#
# Given predictions and true labels, count TP, TN, FP, FN.

# %%
predictions = [1, 0, 1, 1, 0, 1, 0, 0]
true_labels  = [1, 0, 0, 1, 0, 1, 1, 0]

# TODO: compute TP, TN, FP, FN
TP = sum(p == 1 and t == 1 for p, t in zip(predictions, true_labels))
TN = None  # predicted 0, actually 0
FP = None  # predicted 1, actually 0
FN = None  # predicted 0, actually 1

print(f'TP={TP}, TN={TN}, FP={FP}, FN={FN}')
# expected: TP=3, TN=3, FP=1, FN=1

# %% [markdown]
# ## Exercise 2 — Compute Metrics
#
# Use the confusion matrix counts to compute all four metrics.

# %%
# Using TP=3, TN=3, FP=1, FN=1 from Exercise 1
TP, TN, FP, FN = 3, 3, 1, 1
total = TP + TN + FP + FN

# TODO: compute each metric
accuracy  = None  # (TP + TN) / total
precision = None  # TP / (TP + FP)
recall    = None  # TP / (TP + FN)
f1        = None  # 2 * precision * recall / (precision + recall)

print(f'Accuracy:  {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall:    {recall:.3f}')
print(f'F1:        {f1:.3f}')
# expected: all should be 0.75

# %% [markdown]
# ## Exercise 3 — Verify with sklearn
#
# Confirm your manual computations using sklearn.metrics.

# %%
predictions = [1, 0, 1, 1, 0, 1, 0, 0]
true_labels  = [1, 0, 0, 1, 0, 1, 1, 0]

# TODO: compute all 4 metrics using sklearn
sk_accuracy  = accuracy_score(true_labels, predictions)
sk_precision = None  # precision_score(true_labels, predictions)
sk_recall    = None  # recall_score(true_labels, predictions)
sk_f1        = None  # f1_score(true_labels, predictions)

print(f'sklearn accuracy:  {sk_accuracy:.3f}')
print(f'sklearn precision: {sk_precision}')
print(f'sklearn recall:    {sk_recall}')
print(f'sklearn F1:        {sk_f1}')

# %% [markdown]
# ## Next Steps
#
# - Continue to [Cross-Validation](cross_validation.ipynb)
# - Return to the [Model Evaluation page](../../content/ml-foundations/model-evaluation/)
