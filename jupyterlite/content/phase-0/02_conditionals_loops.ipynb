# %% [markdown]
# # Phase 0 — Conditionals and Loops
#
# Covers: `if`/`elif`/`else`, `for`, `while`, range.

# %%
# Exercise 1 — if/else
reward = 1.0
# TODO: print 'Good' if reward > 0, else print 'Bad'

# %%
reward = 1.0
if reward > 0:
    print('Good')
else:
    print('Bad')

# %% [markdown]
# ## Exercise 2 — for loop over rewards

# %%
rewards = [0, 0, 1]
# TODO: use a for loop to print each reward

# %%
rewards = [0, 0, 1]
for r in rewards:
    print(r)

# %% [markdown]
# ## Exercise 3 — sum rewards with a loop

# %%
rewards = [0.5, 0.3, 0.2, 1.0]
total = 0
# TODO: use a for loop to add up all rewards and print the total

# %%
rewards = [0.5, 0.3, 0.2, 1.0]
total = 0
for r in rewards:
    total += r
print(f"Total reward: {total}")

# %% [markdown]
# ## Exercise 4 — episode loop

# %%
# Simulate 5 episodes; print 'Episode 0', 'Episode 1', ..., 'Episode 4'
# TODO: use range(5)

# %%
for ep in range(5):
    print(f"Episode {ep}")
