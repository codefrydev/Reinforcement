# %% [markdown]
# # Phase 0 — Lists and Dictionaries
#
# Covers: lists (append, index, slice), dicts (key-value, get, iteration).

# %%
# Exercise 1 — build a reward list
rewards = []
# TODO: append rewards 0.0, 0.0, 1.0 to the list, then print it

# %%
rewards = []
rewards.append(0.0)
rewards.append(0.0)
rewards.append(1.0)
print(rewards)   # [0.0, 0.0, 1.0]

# %%
# Exercise 2 — Q-table as a dict
Q = {}
# TODO: set Q[('s0', 'up')] = 0.5 and Q[('s0', 'down')] = -0.2
# then print the best action (max value)

# %%
Q = {}
Q[('s0', 'up')] = 0.5
Q[('s0', 'down')] = -0.2
best = max(Q, key=Q.get)
print(f"Best action: {best[1]} with Q={Q[best]}")

# %%
# Exercise 3 — config dict
config = {'gamma': 0.99, 'epsilon': 0.1, 'lr': 0.001}
# TODO: print each key-value pair on its own line

# %%
config = {'gamma': 0.99, 'epsilon': 0.1, 'lr': 0.001}
for key, val in config.items():
    print(f"  {key}: {val}")
