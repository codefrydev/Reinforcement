# %% [markdown]
# # Phase 0 — Hello Python
#
# This notebook covers: variables, print, types, and basic expressions.
#
# **How to use:** Edit the `# TODO` cells and press **Shift+Enter** to run.

# %%
# Run this cell first — it checks your Python version
import sys
print(f"Python {sys.version}")

# %% [markdown]
# ## Exercise 1 — Your first print
#
# Change the message and run.

# %%
# TODO: Change "World" to your name
print("Hello, World")

# %% [markdown]
# ## Exercise 2 — Variables and types

# %%
# TODO: Fill in the variables
reward = None       # replace None with the number 1.0
step_count = None   # replace with the integer 10
agent_name = None   # replace with the string "DQN"

print(f"reward={reward}, steps={step_count}, agent={agent_name}")

# %% [markdown]
# ## Exercise 3 — RL discount calculation

# %%
gamma = 0.9
# TODO: compute gamma squared and gamma cubed
gamma_sq = None   # gamma ** 2
gamma_cu = None   # gamma ** 3
print(f"gamma^1={gamma}, gamma^2={gamma_sq}, gamma^3={gamma_cu}")

# %%
# Solution
gamma = 0.9
gamma_sq = gamma ** 2   # 0.81
gamma_cu = gamma ** 3   # 0.729
print(f"gamma^1={gamma}, gamma^2={gamma_sq:.3f}, gamma^3={gamma_cu:.3f}")
